# %%
# a function with one list and it will return the same list in reverse order

# %%
import numpy as np

def reverse_function(input):
    reverse_list = []
    if(type(input) == np.array):
        input = list(input)
    for i in range (len(list)-1, -1, -1):
        reverse_list.append(list[i])
    return reverse_list


x = 2
y = float(x)
a = ["a","b","c"]
print(reverse_function(a))
# Out:
#   Cell In[4], line 5
#     if(type(list) == )
#                      ^
# SyntaxError: invalid syntax

# %%
class Ship:
    weight: int

    def __init__(self, weight:int):
        self.weight = weight

    def __gt__(self, other):
        if(type(other) == Ship):
            return self.weight > other.weight
    
ships =[Ship(12), Ship(22), Ship(10)]

max(ships)
